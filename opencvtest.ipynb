# %%
import cv2
import numpy as np
import os
from IPython.display import display
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
from PIL import Image as Image
# from sklearn.cluster import KMeans
# from colorspacious import cspace_convert
# from scipy.spatial import distance

# %%
def get_average_color(image_path):
    image = cv2.imread(image_path)
    # cv2.imshow('Loaded Image', image)
    image_rgb = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
    average_color = np.mean(image_rgb, axis=(0, 1))
    return average_color

# %%
def get_average_shade(image_path):
    image = cv2.imread(image_path)
    gray_image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
    average_shade = np.mean(gray_image)
    return average_shade

# %%
colors = []
shades = []
block_height = 100
block_width = 200
for image_name in os.listdir('images'):
    image_path = 'images/{}'.format(image_name)
    image = Image.open(image_path)
    color = get_average_color(image_path)
    shade_intensity = get_average_shade(image_path)
    print(color)
    print(shade_intensity)
    
    color_block_array = np.full((block_height, block_width, 3), color, dtype=np.uint8)
    color_block_array = cv2.addWeighted(color_block_array, 1 - (shade_intensity / 255.0), color_block_array, 0, shade_intensity)
    color_block = Image2.fromarray(color_block_array.astype('uint8'))


    fig, axes = plt.subplots(1, 2, figsize=(10, 5))

    # Display the first image on the left subplot
    axes[0].imshow(image)
    axes[0].axis('off')

    # Display the second image on the right subplot
    axes[1].imshow(color_block)
    axes[1].axis('off')
# Out:
# [ 95.09731451 108.85649397  62.30077895]
# 99.43377299684195
# [92.91819444 80.67385802 72.85298354]
# 83.44953703703703
# [160.47658889 165.11167531 165.95821728]
# 163.81147407407408
# [109.15978893  73.63607176  73.02820591]
# 84.19671669793621
# [103.16310938  62.3225625   25.79512396]
# 70.379025
# [172.88617839 144.10305917 155.79499494]
# 154.04861111111111
# [102.94868556  90.65306738  88.45407949]
# 94.0761537147538
