# %%
import cv2
import numpy as np
import os
from IPython.display import display, Image
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
from PIL import Image
# from sklearn.cluster import KMeans
# from colorspacious import cspace_convert
# from scipy.spatial import distance
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 5
#       3 import os
#       4 from IPython.display import display, Image
# ----> 5 import matplotlib.pyplot as plt
#       6 import matplotlib.image as mpimg
#       7 from PIL import Image
#
# ModuleNotFoundError: No module named 'matplotlib'

# %%
def get_average_color(image_path):
    image = cv2.imread(image_path)
    # cv2.imshow('Loaded Image', image)
    image_rgb = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
    average_color = np.mean(image_rgb, axis=(0, 1))
    return average_color

# %%
def get_average_shade(image_path):
    image = cv2.imread(image_path)
    gray_image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
    average_shade = np.mean(gray_image)
    return average_shade

# %%
colors = []
shades = []
block_height = 100
block_width = 200
for image_name in os.listdir('images'):
    image_path = 'images/{}'.format(image_name)
    # print(image_path)
    # colors.append(get_average_color(image_path))
    # shades.append(get_average_shade(image_path))
    display(Image(image_path))
    color = get_average_color(image_path)
    shade_intensity = get_average_shade(image_path)
    print(color)
    print(shade_intensity)
    
    color_block = np.full((block_height, block_width, 3), color, dtype=np.uint8)
    color_block = cv2.addWeighted(color_block, 1 - (shade_intensity / 255.0), color_block, 0, shade_intensity)
    # plt.imsave('temp.png', color_block) #, cmap='gray')
    image = Image.fromarray(color_block.astype('uint8'))
    image.save('temp.png')
    # cv2.imshow('Color Block', color_block)
    # cv2.waitKey(0)
    # cv2.destroyAllWindows()
# Out:
# [ 95.09731451 108.85649397  62.30077895]
# [92.91819444 80.67385802 72.85298354]
# [160.47658889 165.11167531 165.95821728]
# [109.15978893  73.63607176  73.02820591]
# [103.16310938  62.3225625   25.79512396]
# The kernel failed to start as the Python Environment '.venv' is no longer available. Consider selecting another kernel or refreshing the list of Python Environments.

# %%
display('/images/Opossum.jpg')
# Out:
# '/images/Opossum.jpg'
